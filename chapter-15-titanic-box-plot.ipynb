# %%
import seaborn as sns

titanic = sns.load_dataset('titanic')
print(titanic['fare'].describe())
titanic['fare'].hist(bins=30, edgecolor='black')
plt.title('Histogram of Titanic Fares')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.show()

titanic.boxplot(column='fare')
plt.title('Boxplot of Titanic Fares')
plt.ylabel('Fare')
plt.show()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64
